# %%
import os

from moviepy.editor import VideoFileClip, concatenate_audioclips

src = 'videos'
videos = os.listdir(src)
videos.sort()

videos = [v for v in videos if v.endswith('.mp4')]
videos = [f'{src}/{v}' for v in videos]

audio = [VideoFileClip(v).audio for v in videos]
audio = concatenate_audioclips(audio)
audio.write_audiofile("podcast.mp3")
# Out:
#
#
#
# chunk:  79%|███████▉  | 9153/11568 [48:34<00:09, 243.63it/s, now=None]
# MoviePy - Writing audio in podcast.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 14
#      12 audio = [VideoFileClip(v).audio for v in videos]
#      13 audio = concatenate_audioclips(audio)
# ---> 14 audio.write_audiofile("podcast.mp3")
#
# File ~/Documentos/netzun/venv/lib/python3.10/site-packages/decorator.py:232, in fun(*args, **kw)
#     230 evaldict = dict(_call_=caller, _func_=func)
#     231 es = ''
# --> 232 for i, extra in enumerate(extras):
#     233     ex = '_e%d_' % i
#     234     evaldict[ex] = extra
#
# File ~/Documentos/netzun/venv/lib/python3.10/site-packages/moviepy/decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# ...

# %%
from moviepy.editor import VideoFileClip, concatenate_audioclips

videos = ["videos/video1.mp4","videos/video2.mp4"]
videos = [VideoFileClip(v) for v in videos]
audio = [v.audio for v in videos]

final_audio = concatenate_audioclips(audio)
final_audio.write_audiofile("final_audio.mp3")

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips
from tqdm import tqdm

    final_audio = concatenate_audioclips([video1.audio, video2.audio])

with tqdm(total=final_audio.duration, unit="s") as pbar:
    def update_pbar(t):
        pbar.update(1)

    final_audio.preview(fps=25, on_progress=update_pbar)

# %%
with open('playlist.txt','w') as file:
    for v in videos:
        file.write(f"file 'videos/{v}'\n")

# %%
command = "ffmpeg -f concat -safe 0 -i playlist.txt -map 0:a:0 -c:a mp3 -y final_audio.mp3"
subprocess.run(command, shell=True, check=True)
# Out:
# ffmpeg version n5.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 12.1.1 (GCC) 20220730
# ...

# %%
command = "ffmpeg -f concat -safe 0 -i playlist.txt -map 0:a:0 -c:a mp3 -y -progress pipe:1 final_audio1.mp3"
subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# Out:
# 8.17kB [00:41, 202B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       5 p = Popen(command, shell=True, stdout=PIPE, stderr=PIPE)
#       7 with tqdm(total=None, unit='B', unit_scale=True, unit_divisor=1024) as pbar:
# ----> 8     for line in p.stderr:
#       9         pbar.update(len(line))
#      11 p.wait()
#
# KeyboardInterrupt:
